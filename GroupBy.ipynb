# %%
import pandas as pd

# %%
pd.read_csv("fortune1000.csv")
output = None

# %%
# Change the Rank col as Index column:
fortune = pd.read_csv("fortune1000.csv", index_col="Rank")
sectors = fortune.groupby("Sector")

# %%
# ideal grouping = columns with duplicate values
# menas creating segments of datasets

# %%
sectors = fortune.groupby("Sector")

# %%
# fortune is DataFRame
# sector is a section of the DataFrame DataFrameGroupBy
# sections (ie sector) isn't serving any purpose unless any method is called upon.

# %% [markdown]
# # The .groupby() Method:

# %%
fortune = pd.read_csv("fortune1000.csv", index_col="Rank")
sectors = fortune.groupby("Sector")

# %%
len(sectors)
# Out:
# 21

# %%
fortune["Sector"].nunique()
# Out:
# 21

# %%
sectors.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
fortune["Sector"].value_counts()
# Out:
# Financials                      139
# Energy                          122
# Technology                      102
# Retailing                        80
# Health Care                      75
# Business Services                51
# Industrials                      46
# Materials                        43
# Food, Beverages & Tobacco        43
# Wholesalers                      40
# Transportation                   36
# Chemicals                        30
# Household Products               28
# Engineering & Construction       26
# Media                            25
# Hotels, Resturants & Leisure     25
# Motor Vehicles & Parts           24
# Aerospace & Defense              20
# Telecommunications               15
# Apparel                          15
# Food and Drug Stores             15
# Name: Sector, dtype: int64

# %%
# Pulls the 1st row from each sector:
sectors.first().head(3)
# Out:
#                            Company               Industry       Location  \
# Sector
# Aerospace & Defense         Boeing  Aerospace and Defense    Chicago, IL
# Apparel                       Nike                Apparel  Beaverton, OR
# Business Services    ManpowerGroup         Temporary Help  Milwaukee, WI
#
#                      Revenue  Profits  Employees
# Sector
# Aerospace & Defense    96114     5176     161400
# Apparel                30601     3273      62600
# Business Services      19330      419      27000

# %%
# Pulls the 1st row from each sector:
sectors.last().head(3)
# Out:
#                                    Company               Industry  \
# Sector
# Aerospace & Defense  Delta Tucker Holdings  Aerospace and Defense
# Apparel                              Guess                Apparel
# Business Services    DeVry Education Group              Education
#
#                               Location  Revenue  Profits  Employees
# Sector
# Aerospace & Defense         McLean, VA     1923     -133      12000
# Apparel                Los Angeles, CA     2204       82      13500
# Business Services    Downers Grove, IL     1910      140      11770

# %%
# It gives dictionary, keys=Sectors, and Values=list of all the rows
sectors.groups
# Out:
# {'Aerospace & Defense': [24, 45, 60, 88, 118, 120, 209, 245, 282, 378, 389, 490, 560, 605, 785, 788, 836, 903, 958, 987], 'Apparel': [91, 231, 340, 354, 448, 547, 575, 597, 683, 695, 726, 794, 877, 882, 917], 'Business Services': [144, 186, 199, 204, 221, 248, 249, 294, 307, 312, 355, 392, 404, 440, 467, 468, 481, 485, 492, 503, 545, 626, 635, 652, 677, 694, 714, 729, 734, 735, 737, 744, 767, 776, 777, 783, 791, 792, 796, 801, 803, 816, 819, 820, 869, 870, 886, 939, 951, 952, 993], 'Chemicals': [56, 101, 182, 189, 206, 253, 262, 277, 288, 296, 316, 538, 549, 555, 566, 580, 613, 624, 654, 668, 717, 720, 724, 758, 761, 829, 865, 898, 934, 949], 'Energy': [2, 14, 30, 32, 42, 65, 90, 95, 98, 104, 115, 117, 121, 162, 163, 165, 166, 175, 178, 188, 190, 192, 193, 198, 214, 216, 217, 223, 225, 229, 243, 246, 247, 257, 272, 274, 279, 289, 319, 322, 324, 343, 348, 349, 350, 363, 364, 384, 387, 388, 394, 402, 403, 410, 425, 437, 438, 445, 458, 475, 483, 493, 507, 522, 541, 548, 556, 558, 569, 5
# ...

# %%
# eg. 24 is under A&D
fortune.loc[24]
# Out:
# Company                     Boeing
# Sector         Aerospace & Defense
# Industry     Aerospace and Defense
# Location               Chicago, IL
# Revenue                      96114
# Profits                       5176
# Employees                   161400
# Name: 24, dtype: object

# %% [markdown]
# # Retrieve a Group with the .get_group() Method:

# %%
fortune = pd.read_csv("fortune1000.csv", index_col="Rank")
sectors = fortune.groupby("Sector")

# %%
sectors.get_group("Energy").head(3)
# Out:
#           Company  Sector            Industry       Location  Revenue  \
# Rank
# 2     Exxon Mobil  Energy  Petroleum Refining     Irving, TX   246204
# 14        Chevron  Energy  Petroleum Refining  San Ramon, CA   131118
# 30    Phillips 66  Energy  Petroleum Refining    Houston, TX    87169
#
#       Profits  Employees
# Rank
# 2       16150      75600
# 14       4587      61500
# 30       4227      14000

# %%
sectors.get_group("Technology").head(3)
# Out:
#          Company      Sector                         Industry       Location  \
# Rank
# 3          Apple  Technology      Computers, Office Equipment  Cupertino, CA
# 18    Amazon.com  Technology  Internet Services and Retailing    Seattle, WA
# 20            HP  Technology      Computers, Office Equipment  Palo Alto, CA
#
#       Revenue  Profits  Employees
# Rank
# 3      233715    53394     110000
# 18     107006      596     230800
# 20     103355     4554     287000

# %% [markdown]
# # Method on the GroupBy Object and DataFrame Column:

# %%
# It looks at the left-most column (Company) and sort in Z-A.
sectors.max().head(3)
# Out:
#                                   Company               Industry  \
# Sector
# Aerospace & Defense              Woodward  Aerospace and Defense
# Apparel              Wolverine World Wide                Apparel
# Business Services           Western Union       Waste Management
#
#                               Location  Revenue  Profits  Employees
# Sector
# Aerospace & Defense        Wichita, KS    96114     7608     197200
# Apparel              Winston-Salem, NC    30601     3273      65300
# Business Services             Troy, MI    19330     6328     216500

# %%
# It looks at the left-most column (Company) and sort in A-Z.
sectors.min().head(3)
# Out:
#                             Company                Industry       Location  \
# Sector
# Aerospace & Defense   B/E Aerospace   Aerospace and Defense     Berwyn, PA
# Apparel                    Carter’s                 Apparel    Atlanta, GA
# Business Services    ABM Industries  Advertising, marketing  Arlington, VA
#
#                      Revenue  Profits  Employees
# Sector
# Aerospace & Defense     1923     -240       6955
# Apparel                 2204       82       5978
# Business Services       1910    -1481       2400

# %%
# Sum applies to numeric columns
sectors.sum().head(3)
# Out:
#                      Revenue  Profits  Employees
# Sector
# Aerospace & Defense   357940    28742     968057
# Apparel                95968     8236     346397
# Business Services     272195    28227    1361050

# %%
# Proof:
sectors.get_group("Apparel")["Revenue"].sum()
# Out:
# 95968

# %%
sectors.mean().head(3)
# Out:
#                           Revenue      Profits     Employees
# Sector
# Aerospace & Defense  17897.000000  1437.100000  48402.850000
# Apparel               6397.866667   549.066667  23093.133333
# Business Services     5337.156863   553.470588  26687.254902

# %%
sectors["Revenue"].sum().head()
# Out:
# Sector
# Aerospace & Defense     357940
# Apparel                  95968
# Business Services       272195
# Chemicals               243897
# Energy                 1517809
# Name: Revenue, dtype: int64

# %%
sectors["Employees"].sum().head(3)
# Out:
# Sector
# Aerospace & Defense     968057
# Apparel                 346397
# Business Services      1361050
# Name: Employees, dtype: int64

# %%
sectors["Profits"].max().head(3)
# Out:
# Sector
# Aerospace & Defense    7608
# Apparel                3273
# Business Services      6328
# Name: Profits, dtype: int64

# %%
# Avg. # of employees working in a company:
sectors["Employees"].mean()
# Out:
# Sector
# Aerospace & Defense             48402.850000
# Apparel                         23093.133333
# Business Services               26687.254902
# Chemicals                       15455.033333
# Energy                           9745.303279
# Engineering & Construction      15642.615385
# Financials                      24172.287770
# Food and Drug Stores            93026.533333
# Food, Beverages & Tobacco       28177.488372
# Health Care                     35710.520000
# Hotels, Resturants & Leisure    99369.800000
# Household Products              23072.785714
# Industrials                     33591.934783
# Materials                       14840.069767
# Media                           22012.560000
# Motor Vehicles & Parts          45106.666667
# Retailing                       77845.362500
# Technology                      35087.735294
# Telecommunications              55497.866667
# Transportation                  42688.694444
# Wholesalers                     13139.925000
# ...

# %%
sectors[["Revenue", "Profits"]].sum()
# Out:
#                               Revenue  Profits
# Sector
# Aerospace & Defense            357940    28742
# Apparel                         95968     8236
# Business Services              272195    28227
# Chemicals                      243897    22628
# Energy                        1517809   -73447
# Engineering & Construction     153983     5304
# Financials                    2217159   260209
# Food and Drug Stores           483769    16759
# Food, Beverages & Tobacco      555967    51417
# Health Care                   1614707   106114
# Hotels, Resturants & Leisure   169546    20697
# Household Products             234737    14428
# Industrials                    497581    20764
# Materials                      259145     4428
# Media                          220764    24347
# Motor Vehicles & Parts         482540    25898
# Retailing                     1465076    47830
# Technology                    1377600   180473
# Telecommunications             461834    48637
# ...

# %% [markdown]
# # Grouping by Multiple Columns:

# %%
fortune = pd.read_csv("fortune1000.csv", index_col="Rank")
sectors = fortune.groupby("Sector")

# %%
# Group by more than one column. Group by Sector and Industry.

# %%
fortune = pd.read_csv("fortune1000.csv", index_col="Rank")
sectors = fortune.groupby(["Sector", "Industry"])
fortune.head(3)
# Out:
#           Company      Sector                     Industry         Location  \
# Rank
# 1         Walmart   Retailing        General Merchandisers  Bentonville, AR
# 2     Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 3           Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#       Revenue  Profits  Employees
# Rank
# 1      482130    14694    2300000
# 2      246204    16150      75600
# 3      233715    53394     110000

# %%
sectors.size().head(3)
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense     20
# Apparel              Apparel                   15
# Business Services    Advertising, marketing     2
# dtype: int64

# %%
sectors.sum().head(3)
# Out:
#                                             Revenue  Profits  Employees
# Sector              Industry
# Aerospace & Defense Aerospace and Defense    357940    28742     968057
# Apparel             Apparel                   95968     8236     346397
# Business Services   Advertising, marketing    22748     1549     124100

# %%
sectors["Revenue"].sum().head(3)
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense     357940
# Apparel              Apparel                    95968
# Business Services    Advertising, marketing     22748
# Name: Revenue, dtype: int64

# %%
sectors["Employees"].mean().head(3)
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense     48402.850000
# Apparel              Apparel                   23093.133333
# Business Services    Advertising, marketing    62050.000000
# Name: Employees, dtype: float64

# %% [markdown]
# # The .agg() Method:

# %% [markdown]
# ### sectors.agg({"Column" : "action/math",....})

# %%
sectors.agg({"Revenue" : "sum",
            "Profits" : "sum",
            "Employees" : "mean"})
# Out:
#                                                                    Revenue  \
# Sector              Industry
# Aerospace & Defense Aerospace and Defense                           357940
# Apparel             Apparel                                          95968
# Business Services   Advertising, marketing                           22748
#                     Diversified Outsourcing Services                 64829
#                     Education                                         7485
# ...                                                                    ...
# Transportation      Trucking, Truck Leasing                          35950
# Wholesalers         Miscellaneous                                     8982
#                     Wholesalers: Diversified                        176138
#                     Wholesalers: Electronics and Office Equipment   147906
#                     Wholesalers: Food and Grocery                   111774
#
# ...

# %%
sectors.agg({"size", "sum", "mean"}).head(3)
# Out:
# C:\Users\disha.patel\AppData\Local\Temp\ipykernel_26204\2526801117.py:1: FutureWarning: ['Company', 'Location'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   sectors.agg({"size", "sum", "mean"}).head(3)
#                                            Revenue                        \
#                                               size          mean     sum
# Sector              Industry
# Aerospace & Defense Aerospace and Defense       20  17897.000000  357940
# Apparel             Apparel                     15   6397.866667   95968
# Business Services   Advertising, marketing       2  11374.000000   22748
#
#                                            Profits                      \
#                                               size         mean    sum
# Sector              Industry
# Aerospace & Defense Aerospace and Defense       20  1437.100000  28742
# ...

# %%
sectors.agg({"Revenue" : ["sum", "mean"],
            "Profits" : "sum",
            "Employees" : "mean"})
# Out:
#                                                                   Revenue  \
#                                                                       sum
# Sector              Industry
# Aerospace & Defense Aerospace and Defense                          357940
# Apparel             Apparel                                         95968
# Business Services   Advertising, marketing                          22748
#                     Diversified Outsourcing Services                64829
#                     Education                                        7485
# ...                                                                   ...
# Transportation      Trucking, Truck Leasing                         35950
# Wholesalers         Miscellaneous                                    8982
#                     Wholesalers: Diversified                       176138
#                     Wholesalers: Electronics and Office Equipment  147906
# ...

# %% [markdown]
# # Iterating through Groups:

# %%
# Extract the companies with the most highest Profits for each sectors.
sectors["Profits"].max().head(3)
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense     7608
# Apparel              Apparel                   3273
# Business Services    Advertising, marketing    1094
# Name: Profits, dtype: int64

# %%
df = pd.DataFrame(columns = fortune.columns)
df
# Out:
# Empty DataFrame
# Columns: [Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
# Adding to each rows:

# %%
for sector, data in sectors:
    highest_revenue_company_in_group = data.nlargest(1, "Revenue")
    df = df.append(highest_revenue_company_in_group)
    
df
# Out:
# C:\Users\disha.patel\AppData\Local\Temp\ipykernel_26204\1179554042.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(highest_revenue_company_in_group)
# C:\Users\disha.patel\AppData\Local\Temp\ipykernel_26204\1179554042.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(highest_revenue_company_in_group)
# C:\Users\disha.patel\AppData\Local\Temp\ipykernel_26204\1179554042.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(highest_revenue_company_in_group)
# C:\Users\disha.patel\AppData\Local\Temp\ipykernel_26204\1179554042.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
cities = fortune.groupby("Location")
df = pd.DataFrame(columns = fortune.columns)
df
# Out:
# Empty DataFrame
# Columns: [Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
for city, data in cities:
    highest_revenue_in_city = data.nlargest(1, "Revenue")
    df = df.append(highest_revenue_in_city)
df
# Out:
# C:\Users\disha.patel\AppData\Local\Temp\ipykernel_26204\4084646746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(highest_revenue_in_city)
# C:\Users\disha.patel\AppData\Local\Temp\ipykernel_26204\4084646746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(highest_revenue_in_city)
# C:\Users\disha.patel\AppData\Local\Temp\ipykernel_26204\4084646746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(highest_revenue_in_city)
# C:\Users\disha.patel\AppData\Local\Temp\ipykernel_26204\4084646746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
