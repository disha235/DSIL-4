# %% [markdown]
# # Multi-Index:
# ### Index that allows for multi levels/layer/tiers. Multidimensional data-sets.

# %%
import pandas as pd

# %%
pd.read_csv("bigmac.csv")
# Out:
#        Date        Country  Price in US Dollars
# 0    1/2016      Argentina                 2.39
# 1    1/2016      Australia                 3.74
# 2    1/2016         Brazil                 3.35
# 3    1/2016        Britain                 4.22
# 4    1/2016         Canada                 4.14
# ..      ...            ...                  ...
# 647  1/2010         Turkey                 3.83
# 648  1/2010            UAE                 2.99
# 649  1/2010        Ukraine                 1.83
# 650  1/2010  United States                 3.58
# 651  1/2010        Uruguay                 3.32
#
# [652 rows x 3 columns]

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"])
bigmac.head(2)
# Out:
#         Date    Country  Price in US Dollars
# 0 2016-01-01  Argentina                 2.39
# 1 2016-01-01  Australia                 3.74

# %%
bigmac.dtypes
# Out:
# Date                   datetime64[ns]
# Country                        object
# Price in US Dollars           float64
# dtype: object

# %%
bigmac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 652 non-null    datetime64[ns]
#  1   Country              652 non-null    object
#  2   Price in US Dollars  652 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 15.4+ KB

# %% [markdown]
# # Create a MultiIndex with set_index Method:

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"])
bigmac.head(2)
# Out:
#         Date    Country  Price in US Dollars
# 0 2016-01-01  Argentina                 2.39
# 1 2016-01-01  Australia                 3.74

# %%
# Using the keys="string" that string will become the index now:

bigmac.set_index("Date").head(2)
# Out:
#               Country  Price in US Dollars
# Date
# 2016-01-01  Argentina                 2.39
# 2016-01-01  Australia                 3.74

# %%
# It is keys (plural) so we can use multiple strings: 
bigmac.set_index(keys = ["Date", "Country"]).head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Brazil                    3.35

# %%
bigmac.set_index(keys = ["Country", "Date"]).head(3)
# Out:
#                       Price in US Dollars
# Country   Date
# Argentina 2016-01-01                 2.39
# Australia 2016-01-01                 3.74
# Brazil    2016-01-01                 3.35

# %% [markdown]
# ### Which column to put on the outermost layer?
# #### General Best Practice is to take the column with the least number of unique values and put it in the most outer level and continue taht relationship as you proceed downwards.

# %%
# here we have less unique dates than country:
bigmac.nunique()
bigmac.set_index(keys = ["Date", "Country"], inplace=True)

# %%
bigmac.sort_index()
bigmac.sort_index(inplace = True)
bigmac.head(2)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98

# %%
bigmac.index
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %%
bigmac.index.names
# Out:
# FrozenList(['Date', 'Country'])

# %%
type(bigmac.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
bigmac.index[0]
bigmac.index[10]
# Out:
# (Timestamp('2010-01-01 00:00:00'), 'Denmark')

# %% [markdown]
# # Extract Index Level Values with the get_level_values Method:

# %% [markdown]
# ### Get values from any given values of index:

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Brazil                    3.35

# %%
bigmac.index.get_level_values("Date")
bigmac.index.get_level_values(0)
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01',
#                ...
#                '2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01'],
#               dtype='datetime64[ns]', name='Date', length=652, freq=None)

# %%
bigmac.index.get_level_values("Country")
bigmac.index.get_level_values(1)
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Britain', 'Canada', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Czech Republic',
#        ...
#        'Sri Lanka', 'Sweden', 'Switzerland', 'Taiwan', 'Thailand', 'Turkey',
#        'UAE', 'Ukraine', 'United States', 'Uruguay'],
#       dtype='object', name='Country', length=652)

# %% [markdown]
# # Change Index Level Name with the set_names Method:

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.index.set_names(names = ["Day", "Location"], inplace = True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Day        Location
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.index.set_names(names = "Date", level = 0)

bigmac.index.set_names(names = "Date", level = "Day", inplace = True)

# %% [markdown]
# # The sort_index Method on a MultiIndex DataFrame

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])
bigmac.sort_index(inplace=True)
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
bigmac.loc["2010-01-01", "Argentina"]
# Out:
# Price in US Dollars    1.84
# Name: (2010-01-01 00:00:00, Argentina), dtype: float64

# %%
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.iloc[0]
bigmac.iloc[10]
bigmac.iloc[[10, 20, 30, 250]]
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Denmark                   5.99
#            Malaysia                  2.08
#            Singapore                 3.19
# 2012-07-01 Turkey                    4.52

# %% [markdown]
# # The TRANSPOSE Method:

# %%
bigmac =pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])
bigmac.sort_index(inplace=True)
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
bigmac = bigmac.transpose()

# %%
bigmac.loc[("Price in US Dollars",), ("2010-01-01","Sri Lanka")]
# Out:
# Price in US Dollars    1.83
# Name: (2010-01-01 00:00:00, Sri Lanka), dtype: float64

# %%
bigmac.loc[("Price in US Dollars",), ("2010-01-01","Sri Lanka"):("2010-01-01","Ukraine")]
# Out:
# Date                2010-01-01                                            \
# Country              Sri Lanka Sweden Switzerland Taiwan Thailand Turkey
# Price in US Dollars       1.83   5.51         6.3   2.36     2.11   3.83
#
# Date
# Country               UAE Ukraine
# Price in US Dollars  2.99    1.83

# %% [markdown]
# # The swaplevel Method:

# %%
bigmac =pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.swaplevel()
# Out:
#                           Price in US Dollars
# Country       Date
# Argentina     2010-01-01                 1.84
# Australia     2010-01-01                 3.98
# Brazil        2010-01-01                 4.76
# Britain       2010-01-01                 3.67
# Canada        2010-01-01                 3.97
# ...                                       ...
# Ukraine       2016-01-01                 1.54
# United States 2016-01-01                 4.93
# Uruguay       2016-01-01                 3.74
# Venezuela     2016-01-01                 0.66
# Vietnam       2016-01-01                 2.67
#
# [652 rows x 1 columns]

# %%
bigmac.swaplevel(0, 1)
bigmac.swaplevel(1, 0)

bigmac.swaplevel("Date", "Country")
bigmac.swaplevel("Country", "Date")
# Out:
#                           Price in US Dollars
# Country       Date
# Argentina     2010-01-01                 1.84
# Australia     2010-01-01                 3.98
# Brazil        2010-01-01                 4.76
# Britain       2010-01-01                 3.67
# Canada        2010-01-01                 3.97
# ...                                       ...
# Ukraine       2016-01-01                 1.54
# United States 2016-01-01                 4.93
# Uruguay       2016-01-01                 3.74
# Venezuela     2016-01-01                 0.66
# Vietnam       2016-01-01                 2.67
#
# [652 rows x 1 columns]

# %%
bigmac = bigmac.swaplevel(1, 0)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Country   Date
# Argentina 2010-01-01                 1.84
# Australia 2010-01-01                 3.98
# Brazil    2010-01-01                 4.76

# %% [markdown]
# # The .stack() Method:

# %% [markdown]
# ### Stack Method: moves index from column axis to rows axis:

# %%
world = pd.read_csv("worldstats.csv", index_col=["country","year"])
world.head(3)
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12

# %%
world.stack()
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
#                   GDP           2.873600e+12
#             2013  Population    3.765043e+08
#                                     ...
# Zimbabwe    1962  GDP           1.117602e+09
#             1961  Population    3.876638e+06
#                   GDP           1.096647e+09
#             1960  Population    3.752390e+06
#                   GDP           1.052990e+09
# Length: 22422, dtype: float64

# %%
type(world.stack())
# Out:
# pandas.core.series.Series

# %%
world.stack().to_frame()
# Out:
#                                        0
# country    year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08
#                 GDP         2.873600e+12
#            2013 Population  3.765043e+08
# ...                                  ...
# Zimbabwe   1962 GDP         1.117602e+09
#            1961 Population  3.876638e+06
#                 GDP         1.096647e+09
#            1960 Population  3.752390e+06
#                 GDP         1.052990e+09
#
# [22422 rows x 1 columns]

# %% [markdown]
# # The .unstack() Method

# %% [markdown]
# ### Unstack Method: moves/transpose index from rows axis to column axis.

# %%
world = pd.read_csv("worldstats.csv", index_col=["country","year"])
world.head(3)
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12

# %%
s = world.stack()
s.head()
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
#                   GDP           2.873600e+12
#             2013  Population    3.765043e+08
# dtype: float64

# %%
s.unstack()
# Out:
#                   Population           GDP
# country     year
# Afghanistan 1960   8994793.0  5.377778e+08
#             1961   9164945.0  5.488889e+08
#             1962   9343772.0  5.466667e+08
#             1963   9531555.0  7.511112e+08
#             1964   9728645.0  8.000000e+08
# ...                      ...           ...
# Zimbabwe    2011  14255592.0  1.095623e+10
#             2012  14565482.0  1.239272e+10
#             2013  14898092.0  1.349023e+10
#             2014  15245855.0  1.419691e+10
#             2015  15602751.0  1.389294e+10
#
# [11211 rows x 2 columns]

# %%
s.unstack().unstack()
# Out:
#                       Population                                            \
# year                        1960          1961          1962          1963
# country
# Afghanistan         8.994793e+06  9.164945e+06  9.343772e+06  9.531555e+06
# Albania                      NaN           NaN           NaN           NaN
# Algeria             1.112489e+07  1.140486e+07  1.169015e+07  1.198513e+07
# Andorra                      NaN           NaN           NaN           NaN
# Angola                       NaN           NaN           NaN           NaN
# ...                          ...           ...           ...           ...
# West Bank and Gaza           NaN           NaN           NaN           NaN
# World               3.035056e+09  3.076121e+09  3.129064e+09  3.193947e+09
# Yemen, Rep.                  NaN           NaN           NaN           NaN
# Zambia              3.049586e+06  3.142848e+06  3.240664e+06  3.342894e+06
# ...

# %%
s.unstack().unstack().unstack() #3 layer series:
# Out:
#             year  country
# Population  1960  Afghanistan           8.994793e+06
#                   Albania                        NaN
#                   Algeria               1.112489e+07
#                   Andorra                        NaN
#                   Angola                         NaN
#                                             ...
# GDP         2015  West Bank and Gaza    1.267740e+10
#                   World                 7.343364e+13
#                   Yemen, Rep.                    NaN
#                   Zambia                2.120156e+10
#                   Zimbabwe              1.389294e+10
# Length: 28224, dtype: float64

# %%
world = pd.read_csv("worldstats.csv", index_col=["country","year"])
world.head(3)
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12

# %%
s = world.stack()
s.head(3)
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
# dtype: float64

# %%
s.unstack(2).head(3)
# Out:
#                   Population           GDP
# country     year
# Afghanistan 1960   8994793.0  5.377778e+08
#             1961   9164945.0  5.488889e+08
#             1962   9343772.0  5.466667e+08

# %%
s.unstack(0).head(3)
# Out:
# country           Afghanistan  Albania       Algeria  Andorra  Angola  \
# year
# 1960 Population  8.994793e+06      NaN  1.112489e+07      NaN     NaN
#      GDP         5.377778e+08      NaN  2.723638e+09      NaN     NaN
# 1961 Population  9.164945e+06      NaN  1.140486e+07      NaN     NaN
#
# country          Antigua and Barbuda  Arab World  Argentina  Armenia  Aruba  \
# year
# 1960 Population                  NaN         NaN        NaN      NaN    NaN
#      GDP                         NaN         NaN        NaN      NaN    NaN
# 1961 Population                  NaN         NaN        NaN      NaN    NaN
#
# country          ...  Uzbekistan  Vanuatu  Venezuela, RB  Vietnam  \
# year             ...
# 1960 Population  ...         NaN      NaN   8.146845e+06      NaN
#      GDP         ...         NaN      NaN   8.607600e+09      NaN
# 1961 Population  ...         NaN      NaN   8.461684e+06      NaN
#
# ...

# %%
s.unstack(1).head(3)
# Out:
# year                            1960          1961          1962  \
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population           NaN           NaN           NaN
#
# year                            1963          1964          1965  \
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
#             GDP         7.511112e+08  8.000000e+08  1.006667e+09
# Albania     Population           NaN           NaN           NaN
#
# year                            1966          1967          1968  \
# country
# Afghanistan Population  1.014884e+07  1.036860e+07  1.059979e+07
#             GDP         1.400000e+09  1.673333e+09  1.373333e+09
# Albania     Population           NaN           NaN           NaN
#
# year                            1969  ...          2006          2007  \
# country                               ...
# ...

# %%
s.unstack(-1).head(3)
# Out:
#                   Population           GDP
# country     year
# Afghanistan 1960   8994793.0  5.377778e+08
#             1961   9164945.0  5.488889e+08
#             1962   9343772.0  5.466667e+08

# %%
s.unstack("year").head(3)
# Out:
# year                            1960          1961          1962  \
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population           NaN           NaN           NaN
#
# year                            1963          1964          1965  \
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
#             GDP         7.511112e+08  8.000000e+08  1.006667e+09
# Albania     Population           NaN           NaN           NaN
#
# year                            1966          1967          1968  \
# country
# Afghanistan Population  1.014884e+07  1.036860e+07  1.059979e+07
#             GDP         1.400000e+09  1.673333e+09  1.373333e+09
# Albania     Population           NaN           NaN           NaN
#
# year                            1969  ...          2006          2007  \
# country                               ...
# ...

# %%
s.unstack("country").head(3)
# Out:
# country           Afghanistan  Albania       Algeria  Andorra  Angola  \
# year
# 1960 Population  8.994793e+06      NaN  1.112489e+07      NaN     NaN
#      GDP         5.377778e+08      NaN  2.723638e+09      NaN     NaN
# 1961 Population  9.164945e+06      NaN  1.140486e+07      NaN     NaN
#
# country          Antigua and Barbuda  Arab World  Argentina  Armenia  Aruba  \
# year
# 1960 Population                  NaN         NaN        NaN      NaN    NaN
#      GDP                         NaN         NaN        NaN      NaN    NaN
# 1961 Population                  NaN         NaN        NaN      NaN    NaN
#
# country          ...  Uzbekistan  Vanuatu  Venezuela, RB  Vietnam  \
# year             ...
# 1960 Population  ...         NaN      NaN   8.146845e+06      NaN
#      GDP         ...         NaN      NaN   8.607600e+09      NaN
# 1961 Population  ...         NaN      NaN   8.461684e+06      NaN
#
# ...

# %%
s.head(3)
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
# dtype: float64

# %%
s.unstack(level = [1, 0])
# Out:
# year                2015          2014          2013          2012  \
# country       Arab World    Arab World    Arab World    Arab World
# Population  3.920223e+08  3.842226e+08  3.765043e+08  3.688026e+08
# GDP         2.530102e+12  2.873600e+12  2.846994e+12  2.773270e+12
#
# year                2011          2010          2009          2008  \
# country       Arab World    Arab World    Arab World    Arab World
# Population  3.610318e+08  3.531122e+08  3.450542e+08  3.368865e+08
# GDP         2.497945e+12  2.103825e+12  1.798878e+12  2.081343e+12
#
# year                2007          2006  ...          1969          1968  \
# country       Arab World    Arab World  ...      Zimbabwe      Zimbabwe
# Population  3.287666e+08  3.209067e+08  ...  5.036321e+06  4.874113e+06
# GDP         1.641666e+12  1.404190e+12  ...  1.747999e+09  1.479600e+09
#
# year                1967          1966          1965          1964  \
# ...

# %%
s.unstack(level = [0, 1])
# Out:
# country       Arab World                                            \
# year                2015          2014          2013          2012
# Population  3.920223e+08  3.842226e+08  3.765043e+08  3.688026e+08
# GDP         2.530102e+12  2.873600e+12  2.846994e+12  2.773270e+12
#
# country                                                             \
# year                2011          2010          2009          2008
# Population  3.610318e+08  3.531122e+08  3.450542e+08  3.368865e+08
# GDP         2.497945e+12  2.103825e+12  1.798878e+12  2.081343e+12
#
# country                                 ...      Zimbabwe                \
# year                2007          2006  ...          1969          1968
# Population  3.287666e+08  3.209067e+08  ...  5.036321e+06  4.874113e+06
# GDP         1.641666e+12  1.404190e+12  ...  1.747999e+09  1.479600e+09
#
# country                                                             \
# ...

# %%
s.unstack("year")
# Out:
# year                            1960          1961          1962  \
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.112489e+07  1.140486e+07  1.169015e+07
# ...                              ...           ...           ...
# Yemen, Rep. GDP                  NaN           NaN           NaN
# Zambia      Population  3.049586e+06  3.142848e+06  3.240664e+06
#             GDP         6.987397e+08  6.823597e+08  6.792797e+08
# Zimbabwe    Population  3.752390e+06  3.876638e+06  4.006262e+06
#             GDP         1.052990e+09  1.096647e+09  1.117602e+09
#
# year                            1963          1964          1965  \
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
# ...

# %%
s = s.unstack("year", fill_value=0)
s.head(3)
# Out:
# year                            1960          1961          1962  \
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population  0.000000e+00  0.000000e+00  0.000000e+00
#
# year                            1963          1964          1965  \
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
#             GDP         7.511112e+08  8.000000e+08  1.006667e+09
# Albania     Population  0.000000e+00  0.000000e+00  0.000000e+00
#
# year                            1966          1967          1968  \
# country
# Afghanistan Population  1.014884e+07  1.036860e+07  1.059979e+07
#             GDP         1.400000e+09  1.673333e+09  1.373333e+09
# Albania     Population  0.000000e+00  0.000000e+00  0.000000e+00
#
# year                            1969  ...          2006          2007  \
# country                               ...
# ...

# %% [markdown]
# # The Pivot Method:
# ### Used to reorient a data set. Take values in the column and convert into column head.

# %%
import pandas as pd

# %%
pd.read_csv("salesmen.csv")
output=None

# %%
sales = pd.read_csv("salesmen.csv", parse_dates=["Date"])
len(sales)
# Out:
# 1830

# %%
sales["Salesman"].value_counts()
# Out:
# Bob       366
# Ronald    366
# Dave      366
# Jeb       366
# Oscar     366
# Name: Salesman, dtype: int64

# %%
# All are 366 values, so we can change the Salesman into category.

# %%
sales = pd.read_csv("salesmen.csv", parse_dates=["Date"])
sales["Salesman"] = sales["Salesman"].astype("category")

# %%
# Has lot of repeating format. Like 366 times Rob, Ronald, etc keeps repeating.
# So we can pivot to a format that is more readable and saves space.

# %%
# 5 unique values of Salesman chaneg to column headers
# convert revenue values as values for each one of those names:

# %%
# sales.pivot(index, columns, values)
sales.pivot(index = "Date", columns = "Salesman", values = "Revenue")
# Out:
# Salesman     Bob  Dave   Jeb  Oscar  Ronald
# Date
# 2016-01-01  7172  1864  4430   5250    2639
# 2016-01-02  6362  8278  8026   8661    4951
# 2016-01-03  5982  4226  5188   7075    2703
# 2016-01-04  7917  3868  3144   2524    4258
# 2016-01-05  7837  2287   938   2793    7771
# ...          ...   ...   ...    ...     ...
# 2016-12-27  2045  2843  6666    835    2981
# 2016-12-28   100  8888  1243   3073    6129
# 2016-12-29  4115  9490  3498   6424    7662
# 2016-12-30  2577  3594  8858   7088    2570
# 2016-12-31  3845  6830  9717   8408    2619
#
# [366 rows x 5 columns]

# %% [markdown]
# #  The pivot_table() Method:
# ### It allows to aggregate the data frame/data sets to look at the values as a whole.

# %%
foods = pd.read_csv("foods.csv")

# %%
# get info for Sales based on Gender:

foods.pivot_table(values = "Spend", index = "Gender", aggfunc = "mean")
# Out:
#             Spend
# Gender
# Female  50.709629
# Male    49.397623

# %%
foods.pivot_table(values = "Spend", index = "Gender", aggfunc = "sum")
# Out:
#            Spend
# Gender
# Female  25963.33
# Male    24106.04

# %%
# Get info for the Spend based on Item sale:
foods.pivot_table(values = "Spend", index = "Item", aggfunc = "sum")
# Out:
#              Spend
# Item
# Burger     7765.73
# Burrito    8270.44
# Chalupa    7644.52
# Donut      8758.76
# Ice Cream  8886.99
# Sushi      8742.93

# %%
foods.pivot_table(values = "Spend", index = "Gender", aggfunc = "mean")

# %%
# Can provide List to that index parameter
# This will help create a multiindex parameter:

# %%
# Group Gender and then by Items:

foods.pivot_table(values = "Spend", index = ["Gender", "Item"], aggfunc = "sum")
# Out:
#                     Spend
# Gender Item
# Female Burger     4094.30
#        Burrito    4257.82
#        Chalupa    4152.26
#        Donut      4743.00
#        Ice Cream  4032.87
#        Sushi      4683.08
# Male   Burger     3671.43
#        Burrito    4012.62
#        Chalupa    3492.26
#        Donut      4015.76
#        Ice Cream  4854.12
#        Sushi      4059.85

# %%
foods.pivot_table(values = "Spend", index = ["Gender", "Item"], columns = "City", aggfunc = "sum")
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger      1239.04       1639.24   1216.02
#        Burrito      978.95       1458.76   1820.11
#        Chalupa      876.58       1673.33   1602.35
#        Donut       1446.78       1639.26   1656.96
#        Ice Cream   1521.62       1479.22   1032.03
#        Sushi       1480.29       1742.88   1459.91
# Male   Burger      1294.09        938.18   1439.16
#        Burrito     1399.40       1312.93   1300.29
#        Chalupa     1227.77       1114.23   1150.26
#        Donut       1345.27       1249.36   1421.13
#        Ice Cream   1603.63       2191.27   1059.22
#        Sushi       1396.15       1395.88   1267.82

# %%
foods.pivot_table(values = "Spend", index = ["Gender", "Item"], columns = ["Frequency", "City"], aggfunc = "sum")
# Out:
# Frequency           Daily                        Monthly               \
# City             New York Philadelphia Stamford New York Philadelphia
# Gender Item
# Female Burger      262.67       231.68   144.66   171.86       215.05
#        Burrito     224.45       321.57   195.63   122.74        34.28
#        Chalupa      43.19        23.49    95.70   158.37       289.96
#        Donut       478.10       247.40   124.35   284.53        50.25
#        Ice Cream   262.19       177.69    92.88    92.53        74.51
#        Sushi        81.07       348.53   393.27    93.16        78.71
# Male   Burger      319.46       112.70   197.72   187.29       213.14
#        Burrito     236.21       165.76   276.23   147.54        89.58
#        Chalupa      54.09       274.81   192.64   333.76        90.70
#        Donut       230.00       190.71   129.42   183.73       259.29
#        Ice Cream   178.22       148.69    15.17   152.20       386.55
# ...

# %%
foods.pivot_table(values = "Spend", index = ["Gender", "Item"], columns = "City", aggfunc = "count").head(3)
# Out:
# City            New York  Philadelphia  Stamford
# Gender Item
# Female Burger         24            31        27
#        Burrito        23            28        34
#        Chalupa        19            32        25

# %%
foods.pivot_table(values = "Spend", index = ["Gender", "Item"], columns = "City", aggfunc = "max").head(3)
# Out:
# City            New York  Philadelphia  Stamford
# Gender Item
# Female Burger      98.96         97.79     85.06
#        Burrito     92.25         96.79     99.21
#        Chalupa     98.43         99.29     98.78

# %%
pd.pivot_table(data = foods, values = "Spend", index = ["Gender", "Item"], columns = "City", aggfunc = "sum")
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger      1239.04       1639.24   1216.02
#        Burrito      978.95       1458.76   1820.11
#        Chalupa      876.58       1673.33   1602.35
#        Donut       1446.78       1639.26   1656.96
#        Ice Cream   1521.62       1479.22   1032.03
#        Sushi       1480.29       1742.88   1459.91
# Male   Burger      1294.09        938.18   1439.16
#        Burrito     1399.40       1312.93   1300.29
#        Chalupa     1227.77       1114.23   1150.26
#        Donut       1345.27       1249.36   1421.13
#        Ice Cream   1603.63       2191.27   1059.22
#        Sushi       1396.15       1395.88   1267.82

# %% [markdown]
# #  The pd.melt() Method:

# %% [markdown]
# ### Reorient the summarized data into more tabular format:
# #### Opposite to pivot_table()

# %%
sales = pd.read_csv("quarters.csv")

# %%
# Create one line for Boris, q1/2/3 and 4:

# %%
pd.melt(frame = sales, id_vars = "Salesman").head()
# Out:
#   Salesman variable   value
# 0    Boris       Q1  602908
# 1      Bob       Q1   43790
# 2    Tommy       Q1  392668
# 3   Travis       Q1  834663
# 4   Donald       Q1  580935

# %%
pd.melt(frame = sales, id_vars= "Salesman", var_name= "Quarter").head()
# Out:
#   Salesman Quarter   value
# 0    Boris      Q1  602908
# 1      Bob      Q1   43790
# 2    Tommy      Q1  392668
# 3   Travis      Q1  834663
# 4   Donald      Q1  580935

# %%
pd.melt(frame = sales, id_vars="Salesman", var_name="Quarter", value_name="Revenue").head()
# Out:
#   Salesman Quarter  Revenue
# 0    Boris      Q1   602908
# 1      Bob      Q1    43790
# 2    Tommy      Q1   392668
# 3   Travis      Q1   834663
# 4   Donald      Q1   580935
